# %%
#Q-1 write a python program to add two numbers
a=2
b=3
result=a+b
print(result)
# Out:
# 5

# %%
#Q-2 write a python program to find remainder
# when a number is divided by 2
n=31
print(n%2)
# Out:
# 1

# %%
# Q-3 check the type of the variable assigned 
# using input() function
roll_number=input()
type(roll_number)
# Out:
# str

# %%
# Q-4 use comparison operators to find out whether a 
# given variable a is grater than b or not take a=34 
# and b=80
a=input()
b=input()
a==b
# Out:
# True

# %%
# Q-5 write a python program to find average of two 
# numbers enterd by the user
num_1=int(input())
num_2=int(input())
average=(num_1+num_2)/2
print(average)
# Out:
# 20.0

# %%
# Q-6 write a python program to calculate square of a 
# number entered by the user
num=int(input())
sq=num*num
print("square of ",num," is ",sq)
# Out:
# square of  3  is  9
